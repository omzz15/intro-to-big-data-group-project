# %%
import pandas as pd

df = pd.read_csv("/home/omp/Development/Yonsei/group-project/data/raw/101_DT_1B040A3_M_20260114183142.csv", encoding='euc-kr')
# English column names
df.columns = ['haengjeong-guyeog(sigungu)byeol', 'hangmog', 'dan-wi', '2011.01 wol', '2011.02 wol', '2011.03 wol',
       '2011.04 wol', '2011.05 wol', '2011.06 wol', '2011.07 wol', '2011.08 wol',
       '2011.09 wol', '2011.10 wol', '2011.11 wol', '2011.12 wol', '2012.01 wol',
       '2012.02 wol', '2012.03 wol', '2012.04 wol', '2012.05 wol', '2012.06 wol',
       '2012.07 wol', '2012.08 wol', '2012.09 wol', '2012.10 wol', '2012.11 wol',
       '2012.12 wol', '2013.01 wol', '2013.02 wol', '2013.03 wol', '2013.04 wol',
       '2013.05 wol', '2013.06 wol', '2013.07 wol', '2013.08 wol', '2013.09 wol',
       '2013.10 wol', '2013.11 wol', '2013.12 wol', '2014.01 wol', '2014.02 wol',
       '2014.03 wol', '2014.04 wol', '2014.05 wol', '2014.06 wol', '2014.07 wol',
       '2014.08 wol', '2014.09 wol', '2014.10 wol', '2014.11 wol', '2014.12 wol',
       'Unnamed: 51']

df
# Out:
#     haengjeong-guyeog(sigungu)byeol   hangmog dan-wi  2011.01 wol  \
# 0                                전국   총인구수[명]      명   50534731.0
# 1                                전국  남자인구수[명]      명   25318961.0
# 2                                전국  여자인구수[명]      명   25215770.0
# 3                             서울특별시   총인구수[명]      명   10312835.0
# 4                             서울특별시  남자인구수[명]      명    5110837.0
# ..                              ...       ...    ...          ...
# 853                             제주시  남자인구수[명]      명     208343.0
# 854                             제주시  여자인구수[명]      명     209504.0
# 855                            서귀포시   총인구수[명]      명     153621.0
# 856                            서귀포시  남자인구수[명]      명      77316.0
# 857                            서귀포시  여자인구수[명]      명      76305.0
#
#      2011.02 wol  2011.03 wol  2011.04 wol  2011.05 wol  2011.06 wol  \
# 0     50555262.0   50575130.0   50594424.0   50613213.0   50627347.0
# ...

# %%
df = pd.read_csv("registration-2013.csv")
# df.to_csv("registration-2013.csv", index=False)
df
# Out:
#       C행정구역(시군구)별 행정구역(시군구)별   C연령별      연령별    시점    총인구수 (명)   남자인구수 (명)  \
# 0             '00         전국   '000        계  2013  51141463.0  25588336.0
# 1             '00         전국  '0401       0세  2013    421465.0    216177.0
# 2             '00         전국  '0402       1세  2013    486655.0    249946.0
# 3             '00         전국  '0403       2세  2013    474098.0    243428.0
# 4             '00         전국  '0404       3세  2013    472047.0    243430.0
# ...           ...        ...    ...      ...   ...         ...         ...
# 28657      '50130       서귀포시  '4302      96세  2013        51.0         9.0
# 28658      '50130       서귀포시  '4303      97세  2013        41.0         2.0
# 28659      '50130       서귀포시  '4304      98세  2013        29.0         3.0
# 28660      '50130       서귀포시  '4305      99세  2013        14.0         1.0
# 28661      '50130       서귀포시   '440  100세 이상  2013        61.0         6.0
#
#         여자인구수 (명)
# 0      25553127.0
# 1        205288.0
# ...
