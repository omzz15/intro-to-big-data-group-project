# %%
# Combine all the cleaned data into a single dataset for training and evaluation of models

import os
import pandas as pd
import numpy as np

DATA_DIR = "../../data/cleaned"

STATION_PASSENGER_COUNT_DATA_DIR = os.path.join(DATA_DIR, "station-passenger-count")
TAX_DATA_DIR = os.path.join(DATA_DIR, "tax")
STATION_LOCATION_DATA_DIR = os.path.join(DATA_DIR, "station-location")
LAND_PRICE_CHANGE_DATA_DIR = os.path.join(DATA_DIR, "land-price")
DISTRICT_LOCATION_DATA_DIR = os.path.join(DATA_DIR, "district-location")
POPULATION_DATA_DIR = os.path.join(DATA_DIR, "population")

# %%
# Start by loading the station passenger count data (label)
station_passenger_count_df = pd.read_csv(os.path.join(STATION_PASSENGER_COUNT_DATA_DIR, "passenger-count-monthly-2008-2024.csv"))
station_passenger_count_df
# Out:
#               Date  Station Number  Boarding  Line    Total
# 0       2008-01-31             150     False     1  1503741
# 1       2008-02-29             150     False     1  1394346
# 2       2008-03-31             150     False     1  1518669
# 3       2008-04-30             150     False     1  1495350
# 4       2008-05-31             150     False     1  1565671
# ...            ...             ...       ...   ...      ...
# 111275  2024-08-31             828      True     8   197693
# 111276  2024-09-30             828      True     8   196702
# 111277  2024-10-31             828      True     8   228296
# 111278  2024-11-30             828      True     8   233108
# 111279  2024-12-31             828      True     8   227144
#
# [111280 rows x 5 columns]

# %%
# Load the station location data
station_location_df = pd.read_csv(os.path.join(STATION_LOCATION_DATA_DIR, "station-locations.csv"))
station_location_df
# Out:
#      line   name        lat         lng    no
# 0    01호선    소요산  37.948100  127.061034   100
# 1    01호선    동두천  37.927878  127.054790   101
# 2    01호선     보산  37.913702  127.057277   102
# 3    01호선  동두천중앙  37.901885  127.056482   103
# 4    01호선     지행  37.892334  127.055716   104
# ..    ...    ...        ...         ...   ...
# 704   경강선  신둔도예촌  37.317185  127.404760  K416
# 705   경강선     이천  37.265579  127.442260  K417
# 706   경강선     부발  37.260192  127.490277  K418
# 707   경강선  세종대왕릉  37.295309  127.570938  K419
# 708   경강선     여주  37.282701  127.628607  K420
#
# [709 rows x 5 columns]

# %%
# Try to merge the two datasets on station number
# First we need to convert no in station_location_df to be an int
station_location_df['no'] = pd.to_numeric(station_location_df['no'], errors='coerce')

merged_df = pd.merge(station_passenger_count_df, station_location_df, left_on='Station Number', right_on='no', how='left')

# Check how many missing values there are in the merged dataframe
print(merged_df.count())
display(merged_df.isnull().sum())
merged_df
# Out:
# Date              111280
# Station Number    111280
# Boarding          111280
# Line              111280
# Total             111280
# line              105692
# name              105692
# lat               105692
# lng               105692
# no                105692
# dtype: int64
# Date                 0
# Station Number       0
# Boarding             0
# Line                 0
# Total                0
# line              5588
# name              5588
# lat               5588
# lng               5588
# no                5588
# dtype: int64
#               Date  Station Number  Boarding  Line    Total  line name  \
# 0       2008-01-31             150     False     1  1503741  01호선   송내
# 1       2008-02-29             150     False     1  1394346  01호선   송내
# 2       2008-03-31             150     False     1  1518669  01호선   송내
# 3       2008-04-30             150     False     1  1495350  01호선   송내
# 4       2008-05-31             150     False     1  1565671  01호선   송내
# ...            ...             ...       ...   ...      ...   ...  ...
# 111275  2024-08-31             828      True     8   197693   NaN  NaN
# 111276  2024-09-30             828      True     8   196702   NaN  NaN
# 111277  2024-10-31             828      True     8   228296   NaN  NaN
# 111278  2024-11-30             828      True     8   233108   NaN  NaN
# 111279  2024-12-31             828      True     8   227144   NaN  NaN
#
#             lat         lng     no
# 0       37.4876  126.753664  150.0
# 1       37.4876  126.753664  150.0
# 2       37.4876  126.753664  150.0
# 3       37.4876  126.753664  150.0
# 4       37.4876  126.753664  150.0
# ...         ...         ...    ...
# 111275      NaN         NaN    NaN
# 111276      NaN         NaN    NaN
# 111277      NaN         NaN    NaN
# 111278      NaN         NaN    NaN
# 111279      NaN         NaN    NaN
#
# [111280 rows x 10 columns]

# %%
# Most of the data has locations so we will drop rows with missing location data and remove extra columns
merged_df.dropna(subset=['no', 'lat', 'lng'], inplace=True)
merged_df.drop(columns=['no', 'name', 'line'], inplace=True)

merged_df
# Out:
#               Date  Station Number  Boarding  Line    Total       lat  \
# 0       2008-01-31             150     False     1  1503741  37.48760
# 1       2008-02-29             150     False     1  1394346  37.48760
# 2       2008-03-31             150     False     1  1518669  37.48760
# 3       2008-04-30             150     False     1  1495350  37.48760
# 4       2008-05-31             150     False     1  1565671  37.48760
# ...            ...             ...       ...   ...      ...       ...
# 110793  2024-08-31             826      True     8   161087  37.43213
# 110794  2024-09-30             826      True     8   155338  37.43213
# 110795  2024-10-31             826      True     8   171370  37.43213
# 110796  2024-11-30             826      True     8   172851  37.43213
# 110797  2024-12-31             826      True     8   174013  37.43213
#
#                lng
# 0       126.753664
# 1       126.753664
# 2       126.753664
# 3       126.753664
# 4       126.753664
# ...            ...
# 110793  127.129087
# 110794  127.129087
# 110795  127.129087
# 110796  127.129087
# 110797  127.129087
#
# [105692 rows x 7 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point

# Add district information based on lat/lng
district_location_gdf = gpd.read_file(os.path.join(DISTRICT_LOCATION_DATA_DIR, "district-location.geojson"))
district_location_gdf
# Out:
#           GID_2 GID_0     COUNTRY     GID_1 NAME_1    NL_NAME_1    NAME_2  \
# 0     KOR.1.1_2   KOR  SouthKorea   KOR.1_1  Busan  부산광역시|釜山廣域市       Buk
# 1     KOR.1.2_2   KOR  SouthKorea   KOR.1_1  Busan  부산광역시|釜山廣域市  Busanjin
# 2     KOR.1.3_2   KOR  SouthKorea   KOR.1_1  Busan  부산광역시|釜山廣域市      Dong
# 3     KOR.1.4_2   KOR  SouthKorea   KOR.1_1  Busan  부산광역시|釜山廣域市   Dongnae
# 4     KOR.1.5_2   KOR  SouthKorea   KOR.1_1  Busan  부산광역시|釜山廣域市   Gangseo
# ..          ...   ...         ...       ...    ...          ...       ...
# 224  KOR.17.1_2   KOR  SouthKorea  KOR.17_1  Ulsan  울산광역시|蔚山廣域市       Buk
# 225  KOR.17.2_2   KOR  SouthKorea  KOR.17_1  Ulsan  울산광역시|蔚山廣域市      Dong
# 226  KOR.17.3_2   KOR  SouthKorea  KOR.17_1  Ulsan  울산광역시|蔚山廣域市      Jung
# 227  KOR.17.4_2   KOR  SouthKorea  KOR.17_1  Ulsan  울산광역시|蔚山廣域市       Nam
# 228  KOR.17.5_2   KOR  SouthKorea  KOR.17_1  Ulsan  울산광역시|蔚山廣域市      Ulju
#
#     VARNAME_2 NL_NAME_2 TYPE_2 ENGTYPE_2 CC_2 HASC_2  \
# 0          NA        NA     Gu  District   NA     NA
# 1          NA        NA     Gu  District   NA     NA
# 2          NA        NA     Gu  District   NA     NA
# 3          NA        NA     Gu  District   NA     NA
# 4          NA        NA     Gu  District   NA     NA
# ..        ...       ...    ...       ...  ...    ...
# 224        NA        NA     Gu  District   NA     NA
# 225        NA        NA     Gu  District   NA     NA
# 226        NA        NA     Gu  District   NA     NA
# 227        NA        NA     Gu  District   NA     NA
# 228        NA        NA    Gun    County   NA     NA
#
#                                               geometry
# 0    MULTIPOLYGON (((129.0256 35.1917, 129.0211 35....
# 1    MULTIPOLYGON (((129.0332 35.1371, 129.0256 35....
# 2    MULTIPOLYGON (((129.0365 35.1129, 129.0323 35....
# 3    MULTIPOLYGON (((129.116 35.2011, 129.1143 35.1...
# 4    MULTIPOLYGON (((128.7742 35.0148, 128.7763 35....
# ..                                                 ...
# 224  MULTIPOLYGON (((129.4133 35.5547, 129.4076 35....
# 225  MULTIPOLYGON (((129.3998 35.4666, 129.4065 35....
# 226  MULTIPOLYGON (((129.3515 35.5594, 129.3493 35....
# 227  MULTIPOLYGON (((129.3665 35.5424, 129.3694 35....
# 228  MULTIPOLYGON (((129.3027 35.3323, 129.2999 35....
#
# [229 rows x 14 columns]

# %%
merged_gdf = gpd.GeoDataFrame(
    merged_df,
    geometry=gpd.points_from_xy(merged_df.lng, merged_df.lat),
    crs="EPSG:4326"
)

district_location_gdf = district_location_gdf.to_crs("EPSG:4326")

stations_with_district = gpd.sjoin(
    merged_gdf,
    district_location_gdf[["NAME_1", "NAME_2", "geometry"]],
    how="left",
    predicate="within"
)

# %%
stations_with_district
# Out:
#               Date  Station Number  Boarding  Line    Total       lat  \
# 0       2008-01-31             150     False     1  1503741  37.48760
# 1       2008-02-29             150     False     1  1394346  37.48760
# 2       2008-03-31             150     False     1  1518669  37.48760
# 3       2008-04-30             150     False     1  1495350  37.48760
# 4       2008-05-31             150     False     1  1565671  37.48760
# ...            ...             ...       ...   ...      ...       ...
# 110793  2024-08-31             826      True     8   161087  37.43213
# 110794  2024-09-30             826      True     8   155338  37.43213
# 110795  2024-10-31             826      True     8   171370  37.43213
# 110796  2024-11-30             826      True     8   172851  37.43213
# 110797  2024-12-31             826      True     8   174013  37.43213
#
#                lng                    geometry  index_right       NAME_1  \
# 0       126.753664   POINT (126.75366 37.4876)         81.0  Gyeonggi-do
# 1       126.753664   POINT (126.75366 37.4876)         81.0  Gyeonggi-do
# 2       126.753664   POINT (126.75366 37.4876)         81.0  Gyeonggi-do
# 3       126.753664   POINT (126.75366 37.4876)         81.0  Gyeonggi-do
# 4       126.753664   POINT (126.75366 37.4876)         81.0  Gyeonggi-do
# ...            ...                         ...          ...          ...
# 110793  127.129087  POINT (127.12909 37.43213)         99.0  Gyeonggi-do
# 110794  127.129087  POINT (127.12909 37.43213)         99.0  Gyeonggi-do
# 110795  127.129087  POINT (127.12909 37.43213)         99.0  Gyeonggi-do
# 110796  127.129087  POINT (127.12909 37.43213)         99.0  Gyeonggi-do
# 110797  127.129087  POINT (127.12909 37.43213)         99.0  Gyeonggi-do
#
#           NAME_2
# 0        Bucheon
# 1        Bucheon
# 2        Bucheon
# 3        Bucheon
# 4        Bucheon
# ...          ...
# 110793  Seongnam
# 110794  Seongnam
# 110795  Seongnam
# 110796  Seongnam
# 110797  Seongnam
#
# [106508 rows x 11 columns]

# %%
stations_with_district.drop(columns=['geometry', 'index_right'], inplace=True)

# %%
stations_with_district.isnull().sum()
# Out:
# Date                 0
# Station Number       0
# Boarding             0
# Line                 0
# Total                0
# lat                  0
# lng                  0
# NAME_1            2040
# NAME_2            2040
# dtype: int64

# %%
stations_with_district.dropna(inplace=True)
stations_with_district.isnull().sum()
# Out:
# Date              0
# Station Number    0
# Boarding          0
# Line              0
# Total             0
# lat               0
# lng               0
# NAME_1            0
# NAME_2            0
# dtype: int64

# %%
merged_df = stations_with_district
merged_df
# Out:
#               Date  Station Number  Boarding  Line    Total       lat  \
# 0       2008-01-31             150     False     1  1503741  37.48760
# 1       2008-02-29             150     False     1  1394346  37.48760
# 2       2008-03-31             150     False     1  1518669  37.48760
# 3       2008-04-30             150     False     1  1495350  37.48760
# 4       2008-05-31             150     False     1  1565671  37.48760
# ...            ...             ...       ...   ...      ...       ...
# 110793  2024-08-31             826      True     8   161087  37.43213
# 110794  2024-09-30             826      True     8   155338  37.43213
# 110795  2024-10-31             826      True     8   171370  37.43213
# 110796  2024-11-30             826      True     8   172851  37.43213
# 110797  2024-12-31             826      True     8   174013  37.43213
#
#                lng       NAME_1    NAME_2
# 0       126.753664  Gyeonggi-do   Bucheon
# 1       126.753664  Gyeonggi-do   Bucheon
# 2       126.753664  Gyeonggi-do   Bucheon
# 3       126.753664  Gyeonggi-do   Bucheon
# 4       126.753664  Gyeonggi-do   Bucheon
# ...            ...          ...       ...
# 110793  127.129087  Gyeonggi-do  Seongnam
# 110794  127.129087  Gyeonggi-do  Seongnam
# 110795  127.129087  Gyeonggi-do  Seongnam
# 110796  127.129087  Gyeonggi-do  Seongnam
# 110797  127.129087  Gyeonggi-do  Seongnam
#
# [104468 rows x 9 columns]

# %%
# Add Tax Data
tax_df = pd.read_csv(os.path.join(TAX_DATA_DIR, "tax-data.csv"))
tax_df
# Out:
#                                          Type       District  Year     Revenue
# 0                                       Total          Total  2002         NaN
# 1                                       Total      Seoul Rto  2002  37082078.0
# 2                                       Total         Jongno  2002   3253060.0
# 3                                       Total         Jungbu  2002   2444410.0
# 4                                       Total      Namdaemun  2002   5578244.0
# ...                                       ...            ...   ...         ...
# 158580  Comprehensive Real Estate Holding Tax      Tongyeong  2024      5430.0
# 158581  Comprehensive Real Estate Holding Tax          Jinju  2024     58685.0
# 158582  Comprehensive Real Estate Holding Tax           Jeju  2024     66359.0
# 158583  Comprehensive Real Estate Holding Tax  Tax On Lmport  2024         NaN
# 158584  Comprehensive Real Estate Holding Tax      Stamp Tax  2024         NaN
#
# [158585 rows x 4 columns]

# %%
tax_df['Year'] = tax_df['Year'].astype(int)
merged_df['Year'] = pd.DatetimeIndex(merged_df['Date']).year

merged_df = pd.merge(merged_df, tax_df, left_on=['Year', 'NAME_2'], right_on=['Year', 'District'], how='left')
merged_df
# Out:
#                Date  Station Number  Boarding  Line    Total       lat  \
# 0        2008-01-31             150     False     1  1503741  37.48760
# 1        2008-01-31             150     False     1  1503741  37.48760
# 2        2008-01-31             150     False     1  1503741  37.48760
# 3        2008-01-31             150     False     1  1503741  37.48760
# 4        2008-01-31             150     False     1  1503741  37.48760
# ...             ...             ...       ...   ...      ...       ...
# 4158899  2024-12-31             826      True     8   174013  37.43213
# 4158900  2024-12-31             826      True     8   174013  37.43213
# 4158901  2024-12-31             826      True     8   174013  37.43213
# 4158902  2024-12-31             826      True     8   174013  37.43213
# 4158903  2024-12-31             826      True     8   174013  37.43213
#
#                 lng       NAME_1    NAME_2  Year  \
# 0        126.753664  Gyeonggi-do   Bucheon  2008
# 1        126.753664  Gyeonggi-do   Bucheon  2008
# 2        126.753664  Gyeonggi-do   Bucheon  2008
# 3        126.753664  Gyeonggi-do   Bucheon  2008
# 4        126.753664  Gyeonggi-do   Bucheon  2008
# ...             ...          ...       ...   ...
# 4158899  127.129087  Gyeonggi-do  Seongnam  2024
# 4158900  127.129087  Gyeonggi-do  Seongnam  2024
# 4158901  127.129087  Gyeonggi-do  Seongnam  2024
# 4158902  127.129087  Gyeonggi-do  Seongnam  2024
# 4158903  127.129087  Gyeonggi-do  Seongnam  2024
#
#                                               Type  District   Revenue
# 0                                            Total   Bucheon  764565.0
# 1                                            Total   Bucheon       NaN
# 2                                     Internal Tax   Bucheon  752804.0
# 3                                     Internal Tax   Bucheon       NaN
# 4                                       Direct Tax   Bucheon  438806.0
# ...                                            ...       ...       ...
# 4158899  Transportation¡¤Energy ¡¤ Environment Tax  Seongnam     -19.0
# 4158900                                Defense Tax  Seongnam       NaN
# 4158901                              Education Tax  Seongnam     118.0
# 4158902          Special Tax For Rural Development  Seongnam   14337.0
# 4158903      Comprehensive Real Estate Holding Tax  Seongnam   16639.0
#
# [4158904 rows x 13 columns]

# %%
merged_df.isnull().sum()
# Out:
# Date                    0
# Station Number          0
# Boarding                0
# Line                    0
# Total                   0
# lat                     0
# lng                     0
# NAME_1                  0
# NAME_2                  0
# Year                    0
# Type                19992
# District            19992
# Revenue           1703308
# dtype: int64

# %%
# Just drop all NA
merged_df.dropna(inplace=True)

# %%
# Add population data
population_df = pd.read_csv(os.path.join(POPULATION_DATA_DIR, "population-by-age-groups.csv"))
population_df
# Out:
#        Unnamed: 0 District        Date  Population_0-5  Population_13-18  \
# 0               0   Andong  2008-01-01            8291             12383
# 1               1   Andong  2008-02-01            8295             12328
# 2               2   Andong  2008-03-01            8274             12313
# 3               3   Andong  2008-04-01            8236             12319
# 4               4   Andong  2008-05-01            8238             12337
# ...           ...      ...         ...             ...               ...
# 54834       54834  Yuseong  2025-08-01           15229             22894
# 54835       54835  Yuseong  2025-09-01           15193             22903
# 54836       54836  Yuseong  2025-10-01           15186             22894
# 54837       54837  Yuseong  2025-11-01           15206             22976
# 54838       54838  Yuseong  2025-12-01           15319             22963
#
#        Population_19-64  Population_6-12  Population_65+  Population_Total  \
# 0                105297            13233           28651            167855
# 1                105082            13158           28873            167736
# 2                104957            13103           29021            167668
# 3                104791            13078           29116            167540
# 4                104652            13032           29127            167386
# ...                 ...              ...             ...               ...
# 54834            255046            25150           47997            366316
# 54835            255116            25039           48265            366516
# 54836            254806            24935           48534            366355
# 54837            255117            24814           48836            366949
# 54838            255290            24769           49193            367534
#
#        Population_Female_0-5  ...  Population_Female_19-64  \
# 0                       3991  ...                    51523
# 1                       3981  ...                    51431
# 2                       3985  ...                    51397
# 3                       3961  ...                    51307
# 4                       3961  ...                    51227
# ...                      ...  ...                      ...
# 54834                   7301  ...                   124123
# 54835                   7295  ...                   124094
# 54836                   7294  ...                   123968
# 54837                   7281  ...                   124146
# 54838                   7331  ...                   124250
#
#        Population_Female_6-12  Population_Female_65+  Population_Female_Total  \
# 0                        6278                  17048                    84297
# 1                        6263                  17157                    84280
# 2                        6244                  17250                    84309
# 3                        6241                  17321                    84269
# 4                        6212                  17347                    84199
# ...                       ...                    ...                      ...
# 54834                   12272                  25899                   180688
# 54835                   12216                  26074                   180777
# 54836                   12163                  26205                   180734
# 54837                   12117                  26347                   181014
# 54838                   12086                  26540                   181314
#
#        Population_Male_0-5  Population_Male_13-18  Population_Male_19-64  \
# 0                     4300                   6926                  53774
# 1                     4314                   6880                  53651
# 2                     4289                   6880                  53560
# 3                     4275                   6880                  53484
# 4                     4277                   6885                  53425
# ...                    ...                    ...                    ...
# 54834                 7928                  11801                 130923
# 54835                 7898                  11805                 131022
# 54836                 7892                  11790                 130838
# 54837                 7925                  11853                 130971
# 54838                 7988                  11856                 131040
#
#        Population_Male_6-12  Population_Male_65+  Population_Male_Total
# 0                      6955                11603                  83558
# 1                      6895                11716                  83456
# 2                      6859                11771                  83359
# 3                      6837                11795                  83271
# 4                      6820                11780                  83187
# ...                     ...                  ...                    ...
# 54834                 12878                22098                 185628
# 54835                 12823                22191                 185739
# 54836                 12772                22329                 185621
# 54837                 12697                22489                 185935
# 54838                 12683                22653                 186220
#
# [54839 rows x 21 columns]

# %%
# Extract year-month from both dataframes for merging
merged_df['YearMonth'] = pd.to_datetime(merged_df['Date']).dt.to_period('M')
population_df['YearMonth'] = pd.to_datetime(population_df['Date']).dt.to_period('M')

merged_df = pd.merge(merged_df, population_df, left_on=['YearMonth', 'NAME_2'], right_on=['YearMonth', 'District'], how='left')
merged_df.drop(columns=['Unnamed: 0', 'Date_y', 'District_y', 'District_x'], inplace=True)
merged_df.rename(columns={'Date_x': 'Date'}, inplace=True)
merged_df
# Out:
#                Date  Station Number  Boarding  Line    Total       lat  \
# 0        2008-01-31             150     False     1  1503741  37.48760
# 1        2008-01-31             150     False     1  1503741  37.48760
# 2        2008-01-31             150     False     1  1503741  37.48760
# 3        2008-01-31             150     False     1  1503741  37.48760
# 4        2008-01-31             150     False     1  1503741  37.48760
# ...             ...             ...       ...   ...      ...       ...
# 2455591  2024-12-31             826      True     8   174013  37.43213
# 2455592  2024-12-31             826      True     8   174013  37.43213
# 2455593  2024-12-31             826      True     8   174013  37.43213
# 2455594  2024-12-31             826      True     8   174013  37.43213
# 2455595  2024-12-31             826      True     8   174013  37.43213
#
#                 lng       NAME_1    NAME_2  Year  ... Population_Female_19-64  \
# 0        126.753664  Gyeonggi-do   Bucheon  2008  ...                  295535
# 1        126.753664  Gyeonggi-do   Bucheon  2008  ...                  295535
# 2        126.753664  Gyeonggi-do   Bucheon  2008  ...                  295535
# 3        126.753664  Gyeonggi-do   Bucheon  2008  ...                  295535
# 4        126.753664  Gyeonggi-do   Bucheon  2008  ...                  295535
# ...             ...          ...       ...   ...  ...                     ...
# 2455591  127.129087  Gyeonggi-do  Seongnam  2024  ...                  308892
# 2455592  127.129087  Gyeonggi-do  Seongnam  2024  ...                  308892
# 2455593  127.129087  Gyeonggi-do  Seongnam  2024  ...                  308892
# 2455594  127.129087  Gyeonggi-do  Seongnam  2024  ...                  308892
# 2455595  127.129087  Gyeonggi-do  Seongnam  2024  ...                  308892
#
#          Population_Female_6-12 Population_Female_65+  \
# 0                         38217                 34527
# 1                         38217                 34527
# 2                         38217                 34527
# 3                         38217                 34527
# 4                         38217                 34527
# ...                         ...                   ...
# 2455591                   25113                 88508
# 2455592                   25113                 88508
# 2455593                   25113                 88508
# 2455594                   25113                 88508
# 2455595                   25113                 88508
#
#          Population_Female_Total  Population_Male_0-5  Population_Male_13-18  \
# 0                         430628                26169                  42352
# 1                         430628                26169                  42352
# 2                         430628                26169                  42352
# 3                         430628                26169                  42352
# 4                         430628                26169                  42352
# ...                          ...                  ...                    ...
# 2455591                   461601                15095                  25361
# 2455592                   461601                15095                  25361
# 2455593                   461601                15095                  25361
# 2455594                   461601                15095                  25361
# 2455595                   461601                15095                  25361
#
#          Population_Male_19-64  Population_Male_6-12  Population_Male_65+  \
# 0                       302800                 41748                21679
# 1                       302800                 41748                21679
# 2                       302800                 41748                21679
# 3                       302800                 41748                21679
# 4                       302800                 41748                21679
# ...                        ...                   ...                  ...
# 2455591                 311829                 26332                72791
# 2455592                 311829                 26332                72791
# 2455593                 311829                 26332                72791
# 2455594                 311829                 26332                72791
# 2455595                 311829                 26332                72791
#
#          Population_Male_Total
# 0                       434748
# 1                       434748
# 2                       434748
# 3                       434748
# 4                       434748
# ...                        ...
# 2455591                 451408
# 2455592                 451408
# 2455593                 451408
# 2455594                 451408
# 2455595                 451408
#
# [2455596 rows x 31 columns]

# %%
merged_df.isnull().sum()
# Out:
# Date                       0
# Station Number             0
# Boarding                   0
# Line                       0
# Total                      0
# lat                        0
# lng                        0
# NAME_1                     0
# NAME_2                     0
# Year                       0
# Type                       0
# Revenue                    0
# YearMonth                  0
# Population_0-5             0
# Population_13-18           0
# Population_19-64           0
# Population_6-12            0
# Population_65+             0
# Population_Total           0
# Population_Female_0-5      0
# Population_Female_13-18    0
# Population_Female_19-64    0
# Population_Female_6-12     0
# Population_Female_65+      0
# Population_Female_Total    0
# Population_Male_0-5        0
# Population_Male_13-18      0
# Population_Male_19-64      0
# Population_Male_6-12       0
# Population_Male_65+        0
# Population_Male_Total      0
# dtype: int64

# %%
# Add Land Price Change Data
land_price_df = pd.read_csv(os.path.join(LAND_PRICE_CHANGE_DATA_DIR, "land-price.csv"))
land_price_df
# Out:
#       District         Land_Type        Date  Price_Change
# 0        Seoul          Dwelling  2005-01-01         0.173
# 1        Seoul          Dwelling  2005-02-01         0.117
# 2        Seoul          Dwelling  2005-03-01         0.375
# 3        Seoul          Dwelling  2005-04-01         0.672
# 4        Seoul          Dwelling  2005-05-01         0.549
# ...        ...               ...         ...           ...
# 93600   Ongjin  Semi-Agriculture  2015-02-01           NaN
# 93601   Ongjin  Semi-Agriculture  2015-03-01           NaN
# 93602   Ongjin  Semi-Agriculture  2015-04-01           NaN
# 93603   Ongjin  Semi-Agriculture  2015-05-01           NaN
# 93604   Ongjin  Semi-Agriculture  2015-06-01           NaN
#
# [93605 rows x 4 columns]

# %%
# # Extract year-month from land_price_df for merging by district and month
# land_price_df['YearMonth'] = pd.to_datetime(land_price_df['Date']).dt.to_period('M')

# merged_df = pd.merge(merged_df, land_price_df, left_on=['YearMonth', 'NAME_2'], right_on=['YearMonth', 'District'], how='left')
# # merged_df.drop(columns=['YearMonth', 'Date_y', 'District_y'], inplace=True)
# merged_df
# Out:
#               Date_x  Station Number  Boarding  Line    Total       lat  \
# 0         2008-01-31             150     False     1  1503741  37.48760
# 1         2008-01-31             150     False     1  1503741  37.48760
# 2         2008-01-31             150     False     1  1503741  37.48760
# 3         2008-01-31             150     False     1  1503741  37.48760
# 4         2008-01-31             150     False     1  1503741  37.48760
# ...              ...             ...       ...   ...      ...       ...
# 16819037  2024-12-31             826      True     8   174013  37.43213
# 16819038  2024-12-31             826      True     8   174013  37.43213
# 16819039  2024-12-31             826      True     8   174013  37.43213
# 16819040  2024-12-31             826      True     8   174013  37.43213
# 16819041  2024-12-31             826      True     8   174013  37.43213
#
#                  lng       NAME_1    NAME_2  Year  ... Population_Male_0-5  \
# 0         126.753664  Gyeonggi-do   Bucheon  2008  ...               26169
# 1         126.753664  Gyeonggi-do   Bucheon  2008  ...               26169
# 2         126.753664  Gyeonggi-do   Bucheon  2008  ...               26169
# 3         126.753664  Gyeonggi-do   Bucheon  2008  ...               26169
# 4         126.753664  Gyeonggi-do   Bucheon  2008  ...               26169
# ...              ...          ...       ...   ...  ...                 ...
# 16819037  127.129087  Gyeonggi-do  Seongnam  2024  ...               15095
# 16819038  127.129087  Gyeonggi-do  Seongnam  2024  ...               15095
# 16819039  127.129087  Gyeonggi-do  Seongnam  2024  ...               15095
# 16819040  127.129087  Gyeonggi-do  Seongnam  2024  ...               15095
# 16819041  127.129087  Gyeonggi-do  Seongnam  2024  ...               15095
#
#           Population_Male_13-18 Population_Male_19-64  Population_Male_6-12  \
# 0                         42352                302800                 41748
# 1                         42352                302800                 41748
# 2                         42352                302800                 41748
# 3                         42352                302800                 41748
# 4                         42352                302800                 41748
# ...                         ...                   ...                   ...
# 16819037                  25361                311829                 26332
# 16819038                  25361                311829                 26332
# 16819039                  25361                311829                 26332
# 16819040                  25361                311829                 26332
# 16819041                  25361                311829                 26332
#
#           Population_Male_65+  Population_Male_Total  District  Land_Type  \
# 0                       21679                 434748       NaN        NaN
# 1                       21679                 434748       NaN        NaN
# 2                       21679                 434748       NaN        NaN
# 3                       21679                 434748       NaN        NaN
# 4                       21679                 434748       NaN        NaN
# ...                       ...                    ...       ...        ...
# 16819037                72791                 451408       NaN        NaN
# 16819038                72791                 451408       NaN        NaN
# 16819039                72791                 451408       NaN        NaN
# 16819040                72791                 451408       NaN        NaN
# 16819041                72791                 451408       NaN        NaN
#
#           Date_y  Price_Change
# 0            NaN           NaN
# 1            NaN           NaN
# 2            NaN           NaN
# 3            NaN           NaN
# 4            NaN           NaN
# ...          ...           ...
# 16819037     NaN           NaN
# 16819038     NaN           NaN
# 16819039     NaN           NaN
# 16819040     NaN           NaN
# 16819041     NaN           NaN
#
# [16819042 rows x 35 columns]

# %%
# merged_df.isnull().sum()
# Out:
# Date_x                            0
# Station Number                    0
# Boarding                          0
# Line                              0
# Total                             0
# lat                               0
# lng                               0
# NAME_1                            0
# NAME_2                            0
# Year                              0
# Type                              0
# Revenue                           0
# YearMonth                         0
# Population_0-5                    0
# Population_13-18                  0
# Population_19-64                  0
# Population_6-12                   0
# Population_65+                    0
# Population_Total                  0
# Population_Female_0-5             0
# Population_Female_13-18           0
# Population_Female_19-64           0
# Population_Female_6-12            0
# Population_Female_65+             0
# Population_Female_Total           0
# Population_Male_0-5               0
# Population_Male_13-18             0
# Population_Male_19-64             0
# Population_Male_6-12              0
# Population_Male_65+               0
# Population_Male_Total             0
# District                     312044
# Land_Type                    312044
# Date_y                       312044
# Price_Change               10325754
# dtype: int64
