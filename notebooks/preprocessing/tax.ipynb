# %% [markdown]
# Data from https://kosis.kr/statHtml/statHtml.do?sso=ok&returnurl=https%3A%2F%2Fkosis.kr%3A443%2FstatHtml%2FstatHtml.do%3Fconn_path%3DI2%26tblId%3DDT_13301_013%26language%3Den%26orgId%3D133%26

# %%
import pandas as pd
import numpy as np
import os

DATA_DIR = '../../data'
RAW_DATA_DIR = os.path.join(DATA_DIR, 'raw')
CLEANED_DATA_DIR = os.path.join(DATA_DIR, 'cleaned')

TAX_RAW_DATA_DIR = os.path.join(RAW_DATA_DIR, 'tax')
TAX_CLEANED_DATA_DIR = os.path.join(CLEANED_DATA_DIR, 'tax')

# %%
tax_df = pd.read_csv(os.path.join(TAX_RAW_DATA_DIR, '133_DT_13301_013_20260115162139.csv'), encoding='euc-kr')
display(tax_df.columns)
display(tax_df)
# Out:
# Index(['By type of tax', 'By district tax office', 'Item', 'UNIT', '2002 Year',
#        '2003 Year', '2004 Year', '2005 Year', '2006 Year', '2007 Year',
#        '2008 Year', '2009 Year', '2010 Year', '2011 Year', '2012 Year',
#        '2013 Year', '2014 Year', '2015 Year', '2016 Year', '2017 Year',
#        '2018 Year', '2019 Year', '2020 Year', '2021 Year', '2022 Year',
#        '2023 Year', '2024 Year', 'Unnamed: 27'],
#       dtype='object')
#                              By type of tax By district tax office  \
# 0                                     Total                  Total
# 1                                     Total              Seoul Rto
# 2                                     Total                 Jongno
# 3                                     Total                 Jungbu
# 4                                     Total              Namdaemun
# ...                                     ...                    ...
# 6890  Comprehensive Real Estate Holding Tax              Tongyeong
# 6891  Comprehensive Real Estate Holding Tax                  Jinju
# 6892  Comprehensive Real Estate Holding Tax                   Jeju
# 6893  Comprehensive Real Estate Holding Tax          Tax On Lmport
# 6894  Comprehensive Real Estate Holding Tax              Stamp Tax
#
#                              Item            UNIT 2002 Year 2003 Year  \
# 0     Tax Revenue[In million won]  In million won       NaN       NaN
# 1     Tax Revenue[In million won]  In million won  37082078  39652254
# 2     Tax Revenue[In million won]  In million won   3253060   3842828
# 3     Tax Revenue[In million won]  In million won   2444410   2519571
# 4     Tax Revenue[In million won]  In million won   5578244   5070271
# ...                           ...             ...       ...       ...
# 6890  Tax Revenue[In million won]  In million won       NaN       NaN
# 6891  Tax Revenue[In million won]  In million won       NaN       NaN
# 6892  Tax Revenue[In million won]  In million won       NaN       NaN
# 6893  Tax Revenue[In million won]  In million won       NaN       NaN
# 6894  Tax Revenue[In million won]  In million won       NaN       NaN
#
#      2004 Year 2005 Year  2006 Year  2007 Year  ...  2016 Year  2017 Year  \
# 0          NaN  93944230  130260883  153062775  ...  233329122  255593190
# 1     38768431  43003723   49234337   59619400  ...   69964067   76963042
# 2      3890928   2993144    3189243    3683704  ...    5274107    5659321
# 3      2007063   1971823    3451423    3464565  ...    2530467    2860813
# 4      5031381   7031400    8315783   10563742  ...   10176566   11591400
# ...        ...       ...        ...        ...  ...        ...        ...
# 6890       NaN       115        691       1156  ...       4140       5709
# 6891       NaN       417       1439       3201  ...      20571      25998
# 6892       NaN      2095       7247      11264  ...      12963      21274
# 6893       NaN         -          -          -  ...          -          -
# 6894       NaN         -          -          -  ...          -          -
#
#       2018 Year  2019 Year  2020 Year  2021 Year  2022 Year  2023 Year  \
# 0     283535518  284412645  277275291  334471443  384249472  335672348
# 1      86937600   90880285   95017952  115649580  134239085  120700049
# 2       5817711    6470634    6254894    8380858    7646290    6697593
# 3       1928312    1851805    1416451    1841790    1992693    1642453
# 4      13928708   13720566   14788765   18231214   20130223   20475908
# ...         ...        ...        ...        ...        ...        ...
# 6890       4113       4374       4992       8599      10107       7062
# 6891      26087      29516      43755      67518      75838      66220
# 6892      24958      38721      42386      70537      85163      74741
# 6893        NaN        NaN        NaN        NaN        NaN          -
# 6894        NaN        NaN        NaN        NaN        NaN          -
#
#       2024 Year Unnamed: 27
# 0     328389625         NaN
# 1     115385296         NaN
# 2       5903139         NaN
# 3       1558253         NaN
# 4      18136318         NaN
# ...         ...         ...
# 6890       5430         NaN
# 6891      58685         NaN
# 6892      66359         NaN
# 6893          -         NaN
# 6894          -         NaN
#
# [6895 rows x 28 columns]

# %%
cleaned_tax_df = tax_df.copy()

# Remove unnecessary columns
cleaned_tax_df.drop(columns=['Unnamed: 27'], inplace=True)

# %%
# Check if we can remove unit column
display(cleaned_tax_df['UNIT'].unique())
display(cleaned_tax_df['Item'].unique())
# Out:
# array(['In million won'], dtype=object)
# array(['Tax Revenue[In million won]'], dtype=object)

# %%
# They both only have one value so we can remove them
cleaned_tax_df.drop(columns=['UNIT', 'Item'], inplace=True)

cleaned_tax_df.rename(columns={'By type of tax': 'Type', 'By district tax office': 'District'}, inplace=True)

# %%
# Convert from wide format (years as columns) to long format
# Note revenue is in units of 1 million won
cleaned_tax_df = cleaned_tax_df.melt(id_vars=['Type', 'District'], var_name='Year', value_name='Revenue')

cleaned_tax_df
# Out:
#                                          Type       District       Year  \
# 0                                       Total          Total  2002 Year
# 1                                       Total      Seoul Rto  2002 Year
# 2                                       Total         Jongno  2002 Year
# 3                                       Total         Jungbu  2002 Year
# 4                                       Total      Namdaemun  2002 Year
# ...                                       ...            ...        ...
# 158580  Comprehensive Real Estate Holding Tax      Tongyeong  2024 Year
# 158581  Comprehensive Real Estate Holding Tax          Jinju  2024 Year
# 158582  Comprehensive Real Estate Holding Tax           Jeju  2024 Year
# 158583  Comprehensive Real Estate Holding Tax  Tax On Lmport  2024 Year
# 158584  Comprehensive Real Estate Holding Tax      Stamp Tax  2024 Year
#
#          Revenue
# 0            NaN
# 1       37082078
# 2        3253060
# 3        2444410
# 4        5578244
# ...          ...
# 158580      5430
# 158581     58685
# 158582     66359
# 158583         -
# 158584         -
#
# [158585 rows x 4 columns]

# %%
# Convert year to int
cleaned_tax_df['Year'] = cleaned_tax_df['Year'].str.removesuffix('Year').astype(int)

# %%
# Replace - with NaN and convert Revenue to numeric
cleaned_tax_df['Revenue'] = pd.to_numeric(cleaned_tax_df['Revenue'].replace('-', np.nan).replace('**', np.nan))

# %%
display(cleaned_tax_df.isnull().sum())
cleaned_tax_df
# Out:
# Type            0
# District        0
# Year            0
# Revenue     77382
# dtype: int64
#                                          Type       District  Year     Revenue
# 0                                       Total          Total  2002         NaN
# 1                                       Total      Seoul Rto  2002  37082078.0
# 2                                       Total         Jongno  2002   3253060.0
# 3                                       Total         Jungbu  2002   2444410.0
# 4                                       Total      Namdaemun  2002   5578244.0
# ...                                       ...            ...   ...         ...
# 158580  Comprehensive Real Estate Holding Tax      Tongyeong  2024      5430.0
# 158581  Comprehensive Real Estate Holding Tax          Jinju  2024     58685.0
# 158582  Comprehensive Real Estate Holding Tax           Jeju  2024     66359.0
# 158583  Comprehensive Real Estate Holding Tax  Tax On Lmport  2024         NaN
# 158584  Comprehensive Real Estate Holding Tax      Stamp Tax  2024         NaN
#
# [158585 rows x 4 columns]

# %%
# Save cleaned data
os.makedirs(TAX_CLEANED_DATA_DIR, exist_ok=True)

cleaned_tax_df.to_csv(os.path.join(TAX_CLEANED_DATA_DIR, 'tax-data.csv'), index=False)
